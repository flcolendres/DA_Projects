# %%
import pandas as pd

df = pd.read_csv('london_weather.csv')
print(df.to_string())
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  min_temp  precipitation  pressure  snow_depth
# 0      19790101          2.0       7.0              52.0       2.3       -4.1      -7.5            0.4  101900.0         9.0
# 1      19790102          6.0       1.7              27.0       1.6       -2.6      -7.5            0.0  102530.0         8.0
# 2      19790103          5.0       0.0              13.0       1.3       -2.8      -7.2            0.0  102050.0         4.0
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6      -6.5            0.0  100840.0         2.0
# 4      19790105          6.0       2.0              29.0       5.6       -0.8      -1.4            0.0  102250.0         1.0
# 5      19790106          5.0       3.8              39.0       8.3       -0.5      -6.6            0.7  102780.0         1.0
# ...

# %%
issues = df[df['min_temp'] > df['max_temp']]
print(len(issues))
# Out:
# 230

# %%
result = df[df['max_temp'] >= df['min_temp']]
result.to_csv('clean_london_weather.csv', index=False)

# %%
print(result)
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101          2.0       7.0              52.0       2.3       -4.1
# 1      19790102          6.0       1.7              27.0       1.6       -2.6
# 2      19790103          5.0       0.0              13.0       1.3       -2.8
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 15335  20201226          NaN       2.1              38.0      10.0        4.9
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
# ...
